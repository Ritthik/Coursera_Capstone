# %%
import pandas as pd

# %%
df=pd.read_pickle("./df_analysis_part1")

# %%
df.columns
# Out:
# Index(['Population', 'Area', 'Population Change', 'Travel', 'Outdoors', 'Food',
#        'Arts', 'Shops', 'Residence', 'Professional',
#        'Distance_to_Downtown [Km]', 'Ratio_commuting', 'Ratio_renting',
#        'Average_income', 'Population_density', 'Population_change_ratio'],
#       dtype='object')

# %%
df
# Out:
#              Population  Area  Population Change    Travel  Outdoors  \
# Postal Code
# M3A             26533.0  4.96            -1019.0  0.806452  1.411290
# M4A             17047.0  4.72              415.0  0.635593  0.423729
# M5A             24755.0  2.51             6180.0  1.195219  1.195219
# M6A             17519.0  5.34             1438.0  0.000000  0.187266
# M9A             14453.0  5.45              -14.0  1.467890  1.467890
# ...                 ...   ...                ...       ...       ...
# M8W             21281.0  7.16            -1254.0  0.000000  0.279330
# M4X             25786.0  1.63            -1070.0  0.000000  1.226994
# M8X              8780.0  2.58              642.0  0.387597  1.937984
# M4Y             13397.0  0.55             1083.0  5.454545  1.818182
# M8Y             28377.0  6.65             -846.0  0.601504  0.902256
#
#                   Food      Arts      Shops  Residence  Professional  \
# Postal Code
# M3A           1.008065  0.201613   1.411290   1.411290      2.217742
# M4A           0.847458  0.211864   2.118644   0.847458      1.483051
# M5A           3.984064  1.195219   5.976096   0.398406      3.984064
# M6A           0.749064  0.187266   5.992509   0.000000      0.561798
# M9A           1.100917  0.366972   1.467890   0.550459      1.651376
# ...                ...       ...        ...        ...           ...
# M8W           1.117318  0.139665   1.396648   0.000000      1.955307
# M4X          14.110429  0.613497   7.361963   0.613497      3.680982
# M8X           1.162791  0.775194   6.201550   0.387597      2.325581
# M4Y          12.727273  1.818182  32.727273   7.272727     14.545455
# M8Y           0.300752  0.451128   0.601504   0.902256      1.954887
#
#              Distance_to_Downtown [Km]  Ratio_commuting  Ratio_renting  \
# Postal Code
# M3A                          11.225608         0.140000       0.225000
# M4A                           9.149625         0.156000       0.234000
# M5A                           2.042772         0.160000       0.312580
# M6A                           9.097721         0.157064       0.216701
# M9A                          11.827349         0.120000       0.178000
# ...                                ...              ...            ...
# M8W                          14.227655         0.112423       0.150581
# M4X                           1.613791         0.235619       0.390414
# M8X                           9.800770         0.118000       0.062000
# M4Y                           0.635299         0.250999       0.570000
# M8Y                           9.480503         0.140252       0.226058
#
#              Average_income  Population_density  Population_change_ratio
# Postal Code
# M3A            34811.000000         5349.395161                -0.036985
# M4A            29657.000000         3611.652542                 0.024952
# M5A            48373.662008         9862.549801                 0.332705
# M6A            34963.894800         3280.711610                 0.089422
# M9A            80618.000000         2651.926606                -0.000968
# ...                     ...                 ...                      ...
# M8W            36165.724543         2972.206704                -0.055647
# M4X            34440.350035        15819.631902                -0.039842
# M8X           110944.000000         3403.100775                 0.078889
# M4Y            37653.000000        24358.181818                 0.087949
# M8Y            46760.994679         4267.218045                -0.028950
#
# [73 rows x 16 columns]

# %%
from sklearn import preprocessing

# %%
X=df.values

# %%
X_scaled = preprocessing.StandardScaler().fit_transform(X)

# %%
df_scaled = pd.DataFrame(X_scaled,columns=['Population', 'Area', 'Population Change','Travel', 'Outdoors', 'Food', 'Arts', 'Shops', 'Residence',
       'Professional', 'Distance_to_Downtown [Km]', 'Ratio_commuting',
       'Ratio_renting', 'Average_income', 'Population_density',
       'Population_change_ratio'])

# %%
import seaborn as sns
sns.pairplot(df[['Travel', 'Outdoors', 'Food', 'Arts', 'Shops', 'Residence',
       'Professional', 'Distance_to_Downtown [Km]', 'Ratio_commuting',
       'Ratio_renting', 'Average_income', 'Population_density',
       'Population_change_ratio']])

# %%
df.corr()["Population_density"][3:]
# Out:
# Travel                       0.813121
# Outdoors                     0.474614
# Food                         0.909420
# Arts                         0.188136
# Shops                        0.654445
# Residence                    0.852728
# Professional                 0.905675
# Distance_to_Downtown [Km]   -0.441215
# Ratio_commuting              0.581641
# Ratio_renting                0.642328
# Average_income              -0.149398
# Population_density           1.000000
# Population_change_ratio     -0.058450
# Name: Population_density, dtype: float64

# %%
df_scaled.corr()["Population_density"][3:]
# Out:
# Travel                       0.813121
# Outdoors                     0.474614
# Food                         0.909420
# Arts                         0.188136
# Shops                        0.654445
# Residence                    0.852728
# Professional                 0.905675
# Distance_to_Downtown [Km]   -0.441215
# Ratio_commuting              0.581641
# Ratio_renting                0.642328
# Average_income              -0.149398
# Population_density           1.000000
# Population_change_ratio     -0.058450
# Name: Population_density, dtype: float64

# %% [markdown]
# ## Quite a few variable have a pretty high correaltion with the Population density. Needless to say the correlation does not change by standardizing the variables

# %%
df_scaled.to_pickle("./df_analysis_scaled")

# %%
df_scaled.describe()
# Out:
#          Population          Area  Population Change        Travel  \
# count  7.300000e+01  7.300000e+01       7.300000e+01  7.300000e+01
# mean  -4.866731e-17  5.475072e-17       3.802134e-18  3.269835e-17
# std    1.006920e+00  1.006920e+00       1.006920e+00  1.006920e+00
# min   -1.476408e+00 -1.152866e+00      -1.116974e+00 -5.828892e-01
# 25%   -6.269063e-01 -7.352287e-01      -4.323058e-01 -5.361899e-01
# 50%   -2.622935e-01 -3.475760e-01      -2.207983e-01 -3.733592e-01
# 75%    3.471467e-01  4.876978e-01       7.237652e-03  1.081754e-01
# max    4.030142e+00  2.468796e+00       4.474108e+00  5.967202e+00
#
#            Outdoors          Food          Arts         Shops     Residence  \
# count  7.300000e+01  7.300000e+01  7.300000e+01  7.300000e+01  7.300000e+01
# mean  -1.977109e-17 -2.889622e-17 -5.478637e-17  1.064597e-17  4.802867e-17
# std    1.006920e+00  1.006920e+00  1.006920e+00  1.006920e+00  1.006920e+00
# min   -6.161915e-01 -4.908892e-01 -6.027327e-01 -6.452584e-01 -3.835990e-01
# 25%   -5.233170e-01 -4.216016e-01 -6.027327e-01 -5.571331e-01 -3.835990e-01
# 50%   -3.383861e-01 -3.312887e-01 -4.143288e-01 -4.165569e-01 -2.776737e-01
# 75%    7.099449e-02 -3.170508e-02  7.685010e-02  9.888914e-02 -2.161280e-02
# max    5.128602e+00  6.912404e+00  4.585620e+00  4.289690e+00  7.044987e+00
#
#        Professional  Distance_to_Downtown [Km]  Ratio_commuting  \
# count  7.300000e+01               7.300000e+01     7.300000e+01
# mean   2.509408e-17               1.058894e-16     3.300252e-16
# std    1.006920e+00               1.006920e+00     1.006920e+00
# min   -4.791519e-01              -1.688778e+00    -1.737038e+00
# 25%   -3.786663e-01              -7.647162e-01    -7.603409e-01
# 50%   -2.741149e-01               6.277682e-02    -1.960361e-01
# 75%    5.612525e-02               7.362116e-01     4.328129e-01
# max    7.576715e+00               2.307180e+00     2.647199e+00
#
#        Ratio_renting  Average_income  Population_density  \
# count   7.300000e+01    7.300000e+01        7.300000e+01
# mean   -1.231891e-16   -2.585451e-17       -4.790688e-17
# std     1.006920e+00    1.006920e+00        1.006920e+00
# min    -1.424556e+00   -6.687959e-01       -7.645575e-01
# 25%    -6.573062e-01   -5.437370e-01       -4.163701e-01
# 50%    -1.371725e-01   -3.334265e-01       -2.475299e-01
# 75%     3.725804e-01   -3.106490e-02        5.192243e-02
# max     3.676963e+00    4.029035e+00        7.387918e+00
#
#        Population_change_ratio
# count             7.300000e+01
# mean             -3.117750e-17
# std               1.006920e+00
# min              -9.640085e-01
# 25%              -5.888650e-01
# 50%              -3.034436e-01
# 75%               1.317854e-01
# max               4.463608e+00
